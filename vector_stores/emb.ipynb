# %%
# Out:
# Running cells with 'langchain_env (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n langchain_env ipykernel --update-deps --force-reinstall'

# %%
from sentence_transformers import SentenceTransformer, util
import os
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

from sentence_transformers import SentenceTransformer, util
import os
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# 1. Initialize the model
model = SentenceTransformer("Qwen/Qwen3-Embedding-4B")

# 2. Your 'Database' (Corpus)
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# --- STEP 2: Prepare your 5 Politician Documents ---
docs = [
    Document(page_content="Imran Khan is the founder of PTI and served as the 22nd PM. Led 1992 World Cup win.", metadata={"person": "Imran Khan"}),
    Document(page_content="Nawaz Sharif is the leader of PML-N and served as PM three times. Focuses on CPEC.", metadata={"person": "Nawaz Sharif"}),
    Document(page_content="Shehbaz Sharif is the current PM, known for 'Punjab Speed' and infrastructure.", metadata={"person": "Shehbaz Sharif"}),
    Document(page_content="Zulfikar Ali Bhutto founded the PPP and initiated Pakistan's nuclear program.", metadata={"person": "Z.A. Bhutto"}),
    Document(page_content="Muhammad Ali Jinnah is the founder of Pakistan and its first Governor-General.", metadata={"person": "Quaid-e-Azam"})
]
